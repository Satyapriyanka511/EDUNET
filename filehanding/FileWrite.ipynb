# %%
file_data=open("demo.txt","a")
file_data.write("\n the last line")
file_data.close()

# %%
fd=open("demo.txt","a")
fd.write("entering the new data")
fd.close()

# %%
fd1=open("sample.txt","x")
fd1.write("the new file created with data")
fd1.close()

# %%
#WAP create file info.txt
#name
#city
#college
#read the file

# %%
info_data=open("info.txt","x")
info_data.write("priya kamuju \n KIET,kakinada")
info_data.close()

# %%
info_data=open("info.txt","a")
info_data.write("\nkonaseema\nindia")
info_data.close()

# %%
info_data=open("info.txt","r")
#info_data.read()
for line in info_data:
    print(line)
# Out:
# priya kamuju
#
#  KIET,kakinada
#
# konaseema
#
# india

# %%
info_data.close()

# %%
import os
#os.remove("index.html")
os.remove("sample.txt")
