# %%
from tensorflow.keras import datasets
# Out:
# c:\Users\Priya\Desktop\EDUNET\CHAPTERDL\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
#CTFAR10 Datasets
data=datasets.cifar10.load_data()
# Out:
# c:\Users\Priya\Desktop\EDUNET\CHAPTERDL\.venv\Lib\site-packages\keras\src\datasets\cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
